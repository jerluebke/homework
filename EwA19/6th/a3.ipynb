# %% [markdown]
# # Aufgabe 3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from math import pi, tau, sqrt
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 300

# %%
def f(x, a, b):
    return a*np.exp(b*x)

# %%
x = np.linspace(0, pi/2, 100)
params = [(sqrt(2), sqrt(3)), (-1, 1.337), (tau, pi)]
[plt.plot(x, f(x, a, b), label='a = %f, b = %f' % (a, b)) for a, b in params]
plt.gca().set(xlabel='x', ylabel='y', title='Plot $f(x) = a\,e^{b\,x}$')
plt.legend()
# Out:
# C:\tools\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
